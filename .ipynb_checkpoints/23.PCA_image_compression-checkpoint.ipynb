# %% [markdown]
# ## Сжатие изображения без потери узнаваемости

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import urllib.request

from scipy.stats import stats
from sklearn.decomposition import PCA

import importlib
import utils          
importlib.reload(utils)

from utils import PCA_image_monochrome_compression, PCA_image_color_compression

# %% [markdown]
# Загрузим картинку и нарисуем ее в монохромный формат

# %%
url = "https://www.dropbox.com/s/xoos0myk285efyu/flower.png?dl=1"
urllib.request.urlretrieve(url, "flower.png")   # сохраняем как flower.png

img = cv2.cvtColor(cv2.imread('flower.png'), cv2.COLOR_BGR2GRAY) # преобразует цветное изображение (BGR) в оттенки серого
plt.imshow(img, cmap = 'gray')
plt.show()

# %%
img.shape
# Out:
# (800, 1200)

# %%
print(f'На картинке {img.shape[0] * img.shape[1]} пикселей ({img.shape[0]} на {img.shape[1]})')
# Out:
# На картинке 2073600 пикселей (1080 на 1920)

# %% [markdown]
# Масштабируем данные, поделив значения в матрице на 255

# %%
img_scaled = img / 255.0

# %% [markdown]
# Обучим PCA с 50-ю компонентами. Снизим размерность.

# %%
pca = PCA(n_components=50)
img_PCA_50 = pca.fit_transform(img_scaled)

prop_var = pca.explained_variance_ratio_
eigenvalues = pca.explained_variance_

PC_numbers = np.arange(pca.n_components_) + 1

print(f'Доля дисперсии, объясняемая первыми 50-ю главными компонентами: {sum(prop_var)}')
# Out:
# Доля дисперсии, объясняемая первыми 50-ю главными компонентами: 0.9854897469350233

# %% [markdown]
# Нарисуем график, на котором отобразим долю дисперсии, объясняемой каждой из первых 50-ти компонент

# %%
plt.plot(PC_numbers,
         prop_var,
         'ro-')
plt.title(f'Доля дисперсии, объясняемая каждой из {len(PC_numbers)} главных компонент', fontsize = 10)
plt.ylabel('Proportion of Variance', fontsize = 8)
plt.xlabel('Number of Component', fontsize = 8)
plt.show()

# %% [markdown]
# Восстановим изображение, используя pca.inverse_transform

# %%
img_reconstructed = pca.inverse_transform(img_PCA_50)

# %%
# Отображение
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Оригинал')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_reconstructed, cmap='gray')
plt.title('Восстановленное (PCA c 50 компонентами)')
plt.axis('off')
plt.show()

# %% [markdown]
# Подберем минимальное количество компонент, при которых сжатое изображение визуально практически не отличается от исходного.
#
# Подбор происходит перебором, ориентируемся на визуальный результат

# %%
img_mono = PCA_image_monochrome_compression(img_original=img, num_of_components=50, show_compression_stats=True)
# Out:
# === Статистика сжатия ===
# Размер изображения: 1080×1920 = 2073600 пикселей
# Количество компонент: 50
# Храним: проекции (1080×50) + компоненты (50×1920) = 150000 чисел
# Коэффициент сжатия (по количеству чисел): 13.82x
# Оригинал (uint8): ~2025.0 KB
# Сжатое представление (float64): ~1171.9 KB
# Реальное сжатие в байтах: 1.73x (с учётом типа данных)
# ...

# %%
img_mono = PCA_image_monochrome_compression(img_original=img, num_of_components=60)

# %%
img_mono = PCA_image_monochrome_compression(img_original=img, num_of_components=75, show_compression_stats=True)
# Out:
# === Статистика сжатия ===
# Размер изображения: 800×1200 = 960000 пикселей
# Количество компонент: 75
# Храним: проекции (800×75) + компоненты (75×1200) = 150000 чисел
# Коэффициент сжатия (по количеству чисел): 6.40x
# Оригинал (uint8): ~937.5 KB
# Сжатое представление (float64): ~1171.9 KB
# Реальное сжатие в байтах: 0.80x (с учётом типа данных)
# ...

# %%
img_mono = PCA_image_monochrome_compression(img_original=img, num_of_components=100)

# %% [markdown]
# Попробуем проделать все действия ноутбука, но уже с цветным изображением.

# %%
img_color = cv2.cvtColor(cv2.imread('flower.png'), cv2.COLOR_BGR2RGB)
plt.imshow(img_color)
plt.show()

# %%
img_compr = PCA_image_color_compression(img_color, 50)

# %%
url = "https://images.wallpaperscraft.ru/image/single/anturium_tsvetok_kapli_1102157_1920x1080.jpg"
urllib.request.urlretrieve(url, "anthurium.jpg")

img = cv2.cvtColor(cv2.imread('anthurium.jpg'), cv2.COLOR_BGR2GRAY)
plt.title('Монохром')
plt.imshow(img, cmap = 'gray')
plt.show()

img_color = cv2.cvtColor(cv2.imread('anthurium.jpg'), cv2.COLOR_BGR2RGB)
plt.title('Оригинал')
plt.imshow(img_color)
plt.show()

# %%
img_compr = PCA_image_color_compression(img_color, 80, show_compression_stats=True)
# Out:
# === Суммарная статистика сжатия (цветное изображение) ===
# Размер изображения: 1080×1920×3 = 6220800 чисел (пикселей×каналы)
# Количество компонент на канал: 80
# Храним: для каждого канала (проекции 1080×80 + компоненты 80×1920)
# Общее число чисел: 720000
# Коэффициент сжатия (по количеству чисел): 8.64x
# Оригинал (uint8): ~6075.0 KB
# Сжатое представление (float64): ~5625.0 KB
# Реальное сжатие в байтах: 1.08x
# ...

# %%
url = 'https://sun9-54.userapi.com/s/v1/ig2/NqSwZVsIqIGTXIMSG0b28A4cgPGBKUkOoS2SJThmi9qtQNl8kKQgecv2ynUAFZ6WJBTvuCYQGXhKdaVhrvK3araN.jpg?quality=95&as=32x43,48x64,72x96,108x144,160x214,240x321,360x481,480x641,540x721,640x855,720x962,958x1280&from=bu&cs=958x0'
urllib.request.urlretrieve(url, "me.jpg")

img = cv2.cvtColor(cv2.imread('me.jpg'), cv2.COLOR_BGR2GRAY)
plt.title('Монохром')
plt.imshow(img, cmap = 'gray')
plt.show()

img_color = cv2.cvtColor(cv2.imread('me.jpg'), cv2.COLOR_BGR2RGB)
plt.title('Оригинал')
plt.imshow(img_color)
plt.show()

# %%
img_compr = PCA_image_color_compression(img_color, 100, show_compression_stats=True)
# Out:
# === Суммарная статистика сжатия (цветное изображение) ===
# Размер изображения: 1280×958×3 = 3678720 чисел (пикселей×каналы)
# Количество компонент на канал: 100
# Храним: для каждого канала (проекции 1280×100 + компоненты 100×958)
# Общее число чисел: 671400
# Коэффициент сжатия (по количеству чисел): 5.48x
# Оригинал (uint8): ~3592.5 KB
# Сжатое представление (float64): ~5245.3 KB
# Реальное сжатие в байтах: 0.68x
# ...
